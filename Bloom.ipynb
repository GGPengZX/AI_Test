# %% [markdown]
# <a href="https://colab.research.google.com/github/GGPengZX/AI_Test/blob/main/Bloom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install huggingface_hub

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
# !git clone https://huggingface.co/bigscience/bloom
# Out:
# fatal: destination path 'bloom' already exists and is not an empty directory.

# %%
from transformers import AutoTokenizer, AutoModel

model = AutoModel.from_pretrained("bigscience/bloom", trust_remote_code=True, device='cuda')
model = model.eval()
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom", trust_remote_code=True)
response, history = model.chat(tokenizer, "你知道langchain吗", history=[])
print(response)
# Out:
# config.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/63.7k [00:00<?, ?B/s]
# ...
# model_00001-of-00072.safetensors:   0%|          | 0.00/7.19G [00:00<?, ?B/s]
# model_00002-of-00072.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model_00003-of-00072.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model_00004-of-00072.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model_00005-of-00072.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model_00006-of-00072.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model_00007-of-00072.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model_00008-of-00072.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model_00009-of-00072.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model_00010-of-00072.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# ...

# %% [markdown]
# 模型共72个文件，一个文件至少4个G，储存不下。
