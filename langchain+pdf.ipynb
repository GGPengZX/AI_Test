# %% [markdown]
# <a href="https://colab.research.google.com/github/GGPengZX/AI_Test/blob/main/langchain%2Bpdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.9/277.9 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.5 MB/s eta 0:00:00
# ...

# %%
# 分割pdf文件
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("/content/8941576.PDF")
pages = loader.load_and_split()
question = '如何提升系统性业务及运营管理能力，构建可持续发展内核动能?'

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = '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'

# %%
# !pip install huggingface_hub

# %%
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.1 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=b5698363eadd8e48ac8e880c72983b1e7a683d2de31fbc19358e64ad86e808aa
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...

# %%
from langchain.embeddings import  HuggingFaceEmbeddings
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])

# %%
repo_id = "THUDM/chatglm3-6b"
llm = HuggingFaceEmbeddings(
    model_name=repo_id
)
llm_chain = LLMChain(prompt=prompt, llm=llm)
print(llm_chain.run(question))
# Out:
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# MODEL_LICENSE:   0%|          | 0.00/4.13k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/7.38k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# configuration_chatglm.py:   0%|          | 0.00/2.33k [00:00<?, ?B/s]
# modeling_chatglm.py:   0%|          | 0.00/55.7k [00:00<?, ?B/s]
# pytorch_model-00001-of-00007.bin:   0%|          | 0.00/1.83G [00:00<?, ?B/s]
# pytorch_model-00002-of-00007.bin:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# pytorch_model-00003-of-00007.bin:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# pytorch_model-00004-of-00007.bin:   0%|          | 0.00/1.82G [00:00<?, ?B/s]
# pytorch_model-00005-of-00007.bin:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# pytorch_model-00006-of-00007.bin:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# pytorch_model-00007-of-00007.bin:   0%|          | 0.00/1.05G [00:00<?, ?B/s]
# ...

# %%
from langchain.vectorstores import FAISS
faiss_index = FAISS.from_documents(pages, llm)
docs = faiss_index.similarity_search(question, k=2)
for doc in docs:
    print(str(doc.metadata["page"]) + ":", doc.page_content[:300])
