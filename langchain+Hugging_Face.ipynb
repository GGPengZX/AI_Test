# %% [markdown]
# <a href="https://colab.research.google.com/github/GGPengZX/AI_Test/blob/main/langchain%2BHugging_Face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install huggingface_hub

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 kB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# !pip install -U transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 30.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ...

# %%
# !pip install -U huggingface_hub

# %%
from langchain import HuggingFaceHub
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from huggingface_hub import InferenceClient
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = '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'
API_TOKEN = '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'
question = "中国的首都是？"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
llm = HuggingFaceHub(repo_id = 'EleutherAI/gpt-j-6b',model_kwargs={"temperature": 0.5, "max_length": 64})
inference = InferenceClient(model="EleutherAI/gpt-j-6b", token=API_TOKEN)
llm_chain = LLMChain(prompt=prompt, llm=llm)

print(llm_chain)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:127: FutureWarning: '__init__' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '1.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
#   warnings.warn(warning_message, FutureWarning)
# prompt=PromptTemplate(input_variables=['question'], template="Question: {question}\nAnswer: Let's think step by step.") llm=HuggingFaceHub(client=InferenceAPI(api_url='https://api-inference.huggingface.co/pipeline/text-generation/EleutherAI/gpt-j-6b', task='text-generation', options={'wait_for_model': True, 'use_gpu': False}), repo_id='EleutherAI/gpt-j-6b', model_kwargs={'temperature': 0.5, 'max_length': 64})

# %%
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.9 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=73ae84ac9f104449f2433fdf7561c80d750796b40c4700c81bd55a1db085745f
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
# 数据私有化部署
from langchain.embeddings import HuggingFaceEmbeddings
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = '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'
embeddings = HuggingFaceEmbeddings(model_name = 'google/flan-t5-xl')
text = u"中国的首都是？"
text_embedding = embeddings.embed_query(text)
print(text_embedding)
# Out:
# .gitattributes:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# flax_model-00001-of-00002.msgpack:   0%|          | 0.00/9.97G [00:00<?, ?B/s]
# flax_model-00002-of-00002.msgpack:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# flax_model.msgpack.index.json:   0%|          | 0.00/51.2k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/53.0k [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/50.8k [00:00<?, ?B/s]
# ...

# %%
from langchain.llms.huggingface_pipeline import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

model_id = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, max_new_tokens=10)
hf = HuggingFacePipeline(pipeline=pipe)

from langchain.prompts import PromptTemplate
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)
chain = prompt | hf
question = "中国的首都是？"
print(chain.invoke({"question": question}))
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  I have only ever thought of using a couple of
