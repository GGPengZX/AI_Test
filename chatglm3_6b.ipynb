# %% [markdown]
# <a href="https://colab.research.google.com/github/GGPengZX/AI_Test/blob/main/chatglm3_6b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.6 MB/s eta 0:00:00
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
# !pip install transformers sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.1 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/THUDM/ChatGLM3
# Out:
# Cloning into 'ChatGLM3'...
# remote: Enumerating objects: 704, done.
# remote: Counting objects: 100% (353/353), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 704 (delta 270), reused 225 (delta 220), pack-reused 351
# Receiving objects: 100% (704/704), 15.59 MiB | 18.75 MiB/s, done.
# Resolving deltas: 100% (400/400), done.

# %%
# !pip install sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.6 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm3-6b",trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm3-6b",trust_remote_code=True,device='cuda')
model = model.eval()
# Out:
# tokenizer.model:   0%|          | 0.00/1.02M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# configuration_chatglm.py:   0%|          | 0.00/2.33k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# - configuration_chatglm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_chatglm.py:   0%|          | 0.00/55.7k [00:00<?, ?B/s]
# quantization.py:   0%|          | 0.00/14.7k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# - quantization.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# ...

# %%
question = "1+1为什么等于2，有什么历史吗？"
response,history = model.chat(tokenizer,question,history=[])
print(response)
# Out:
# 1+1=2是一种基本的数学原理,可以追溯到古代文明时期。以下是一些可能有助于回答这个问题的历史背景和文化因素:
#
# 1. 古代中国:在古代中国,数学被认为是人类文明的一部分,早在周朝时期,就有关于数学的记录和书籍。在《周髀算经》中,提到了“加法”,其中写道:“加法者,盖以前一物,加于后一物,合二为一也。”
#
# 2. 古代印度:在古代印度,数学也是一项重要的学科。在《巴赫沙利手稿》中,有一组算术问题,其中包括加法问题,这些问题可能有助于发展了阿拉伯数字系统。
#
# 3. 欧洲文艺复兴时期:在16世纪和17世纪的欧洲,数学成为一种重要的学科,许多数学家开始研究这个领域。在17世纪,数学家皮亚诺提出了“自然数”的概念,并定义了“加法”的概念。
#
# 4. 现代数学:在现代数学中,1+1=2是一种基本的数学公理,被称为“零元素加法”。这个公理是数学中非常重要的一个基本概念,被广泛应用于数学的各个领域。
#
# 1+1=2的历史是一个涉及到人类文明和数学发展的复杂故事。在不同的文化和历史时期,人们对于数学的理解和应用都不同,但无论如何,加法都是数学中不可或缺的一部分。
